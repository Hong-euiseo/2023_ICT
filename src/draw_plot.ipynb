# %%
print("Hello!")
# Out:
# Hello!

# %%
import pandas as pd
data = {
    "BASE": ["A", "C", "G", "T"],
    "COUNT": [8954, 9594, 5863, 5492]
}
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'BASE': ['A', 'C', 'G', 'T'], 'COUNT': [8954, 9594, 5863, 5492]}

# %%
df = pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   BASE  COUNT
# 0    A   8954
# 1    C   9594
# 2    G   5863
# 3    T   5492

# %%
import pandas as pd
filepath = "C:\\Users\\user\\Desktop\\2023_ICT교육\\2023_ICT\\plot_data.csv"

df = pd.read_csv(filepath)
df
# Out:
#     SEX   AGE     GENE  GROUP ALIVE
# 0     M  22.0   7.2500      3    no
# 1     F  38.0  71.2833      1   yes
# 2     F  26.0   7.9250      3   yes
# 3     F  35.0  53.1000      1   yes
# 4     M  35.0   8.0500      3    no
# ..   ..   ...      ...    ...   ...
# 886   M  27.0  13.0000      2    no
# 887   F  19.0  30.0000      1   yes
# 888   F   NaN  23.4500      3    no
# 889   M  26.0  30.0000      1   yes
# 890   M  32.0   7.7500      3    no
#
# [891 rows x 5 columns]

# %%
import pandas as pd
filepath = "C:\\Users\\user\\Desktop\\2023_ICT교육\\2023_ICT\\plot_data.xlsx"

df = pd.read_excel(filepath)
df
# Out:
#     SEX   AGE     GENE  GROUP ALIVE
# 0     M  22.0   7.2500      3    no
# 1     F  38.0  71.2833      1   yes
# 2     F  26.0   7.9250      3   yes
# 3     F  35.0  53.1000      1   yes
# 4     M  35.0   8.0500      3    no
# ..   ..   ...      ...    ...   ...
# 886   M  27.0  13.0000      2    no
# 887   F  19.0  30.0000      1   yes
# 888   F   NaN  23.4500      3    no
# 889   M  26.0  30.0000      1   yes
# 890   M  32.0   7.7500      3    no
#
# [891 rows x 5 columns]

# %%
import seaborn as sns
sns.barplot(x="GROUP", y="GENE", hue="SEX", data=df)
# Out:
# <Axes: xlabel='GROUP', ylabel='GENE'>

# %%
sns.boxplot(x="GROUP", y="GENE", hue="SEX", data=df)
# Out:
# <Axes: xlabel='GROUP', ylabel='GENE'>

# %%
sns.boxplot(y="AGE", data=df)
# Out:
# <Axes: ylabel='AGE'>

# %%
sns.boxplot(x=df["GROUP"], y=df["GENE"])
# Out:
# <Axes: xlabel='GROUP', ylabel='GENE'>

# %%
sns.boxplot(y=df["AGE"], x=df["GROUP"], hue=df["ALIVE"])
# Out:
# <Axes: xlabel='GROUP', ylabel='AGE'>

# %%
sns.scatterplot(x="AGE", y="GENE", data=df)
# Out:
# <Axes: xlabel='AGE', ylabel='GENE'>

# %%
sns.scatterplot(x="AGE", y="GENE", data=df, hue="SEX")
# Out:
# <Axes: xlabel='AGE', ylabel='GENE'>
